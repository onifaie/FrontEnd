# %% [markdown]
# this file for work on how read excel file and analysis by pandas libraray

# %%
import pandas as pd 
import matplotlib.pyplot  as plt 
import numpy as np
df=pd.read_csv('train_and_test2.csv')
plt.plot(df)
plt.show()
# Out:
# [<matplotlib.lines.Line2D at 0x13526e94700>,
#  <matplotlib.lines.Line2D at 0x13526e947f0>,
#  <matplotlib.lines.Line2D at 0x13526e948b0>,
#  <matplotlib.lines.Line2D at 0x13526e94970>,
#  <matplotlib.lines.Line2D at 0x13526e94a30>,
#  <matplotlib.lines.Line2D at 0x13526e94af0>,
#  <matplotlib.lines.Line2D at 0x13526e94bb0>,
#  <matplotlib.lines.Line2D at 0x13526e94c70>,
#  <matplotlib.lines.Line2D at 0x13526e94d30>,
#  <matplotlib.lines.Line2D at 0x13526e94df0>,
#  <matplotlib.lines.Line2D at 0x13526e79940>,
#  <matplotlib.lines.Line2D at 0x13526e94f10>,
#  <matplotlib.lines.Line2D at 0x13526e94fa0>,
#  <matplotlib.lines.Line2D at 0x13526e9c100>,
#  <matplotlib.lines.Line2D at 0x13526e9c1c0>,
#  <matplotlib.lines.Line2D at 0x13526e9c280>,
#  <matplotlib.lines.Line2D at 0x13526e9c340>,
#  <matplotlib.lines.Line2D at 0x13526e9c400>,
#  <matplotlib.lines.Line2D at 0x13526e9c4c0>,
#  <matplotlib.lines.Line2D at 0x13526e9c580>,
#  <matplotlib.lines.Line2D at 0x13526e9c640>,
#  <matplotlib.lines.Line2D at 0x13526e9c700>,
#  <matplotlib.lines.Line2D at 0x13526e9c7c0>,
#  <matplotlib.lines.Line2D at 0x13526e9c880>,
#  <matplotlib.lines.Line2D at 0x13526e9c940>,
#  <matplotlib.lines.Line2D at 0x13526e9ca00>,
#  <matplotlib.lines.Line2D at 0x13526e9cac0>,
#  <matplotlib.lines.Line2D at 0x13526e9cb80>]
